# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importando os dados e definindo Letras maiúsculas para o título das colunas

# %%
df = pd.read_csv('data_microdados.csv', sep = ',', encoding = 'utf-8', skipinitialspace = True)
df.columns = [x.upper() for x in df.columns]
# Out:
# C:\Users\DMV INFOR\AppData\Local\Temp\ipykernel_10432\3571068956.py:1: DtypeWarning: Columns (19,20,26,27,52,53,63,75,190,191,192,193,225,227,253,264,285,292,303,315,329,341) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data_microdados.csv', sep = ',', encoding = 'utf-8')

# %% [markdown]
# Realizando a limpeza do dados

# %%
pd.set_option('display.max_columns', None)
df = df.rename(columns={'P1_A': 'Idade',
                        'P1_A_1': 'Faixa idade',
                        'P1_B': 'gênero',
                        'P1_C': 'Cor/raca/etnia',
                        'P1_D': 'Pcd',
                        'P1_E': 'Experiência profissional prejudicada',
                        'P1_F': 'Aspectos prejudicados',
                        'P1_G': 'Vive no brasil',
                        'P1_I': 'Estado onde mora',
                        'P1_I_1': 'Uf onde mora',
                        'P1_I_1': 'Região onde mora',
                        'P1_J': 'Mudou de estado?',
                        'P1_K': 'Regiao de origem',
                        'P1_L': 'Nivel de ensino',
                        'P1_M': 'Área de formação'}).drop('P0', axis=1)
df.head()
# Out:
#    Idade Faixa idade     gênero Cor/raca/etnia  Pcd  \
# 0   26.0       25-29  Masculino         Branca  Não
# 1   25.0       25-29  Masculino         Branca  Não
# 2   30.0       30-34  Masculino         Branca  Não
# 3   22.0       22-24   Feminino          Preta  Não
# 4   24.0       22-24   Feminino         Branca  Não
#
#                 Experiência profissional prejudicada  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Sim, acredito que a minha a experiência profis...
# 4  Sim, acredito que a minha a experiência profis...
#
#                                Aspectos prejudicados  Vive no brasil  \
# 0                                                NaN            True
# 1                                                NaN            True
# 2                                                NaN           False
# ...
