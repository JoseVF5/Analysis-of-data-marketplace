# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importando os dados e definindo Letras maiúsculas para o título das colunas

# %%
df = pd.read_csv('data_microdados.csv', sep = ',', encoding = 'utf-8', engine='python')
df.columns = [x.upper() for x in df.columns]

# %% [markdown]
# Realizando a limpeza do dados

# %%
pd.set_option('display.max_columns', None)
df = df.rename(columns={'P1_A': 'Idade',
                        'P1_A_1': 'Faixa idade',
                        'P1_B': 'gênero',
                        'P1_C': 'Cor/raca/etnia',
                        'P1_D': 'Pcd',
                        'P1_E': 'Experiência profissional prejudicada',
                        'P1_F': 'Aspectos prejudicados',
                        'P1_G': 'Vive no brasil',
                        'P1_I': 'Estado onde mora',
                        'P1_I_1': 'Uf onde mora',
                        'P1_I_1': 'Região onde mora',
                        'P1_J': 'Mudou de estado?',
                        'P1_K': 'Regiao de origem',
                        'P1_L': 'Nivel de ensino',
                        'P1_M': 'Área de formação'}).drop('P0', axis=1)
df.head()

# %%
import basedosdados as bd

billing_id = data-marketplace-466013:US.bquxjob_690c1003_1980e510b06

query = """
  SELECT
    dados.p0 as p0,
    dados.p1_a as p1_a,
    dados.p1_a_1 as p1_a_1,
    dados.p1_b as p1_b,
    dados.p1_c as p1_c,
    dados.p1_d as p1_d,
    dados.p1_e as p1_e,
    dados.p1_f as p1_f,
    dados.p1_g as p1_g,
    dados.p1_i as p1_i,
    dados.p1_i_1 as p1_i_1,
    dados.p1_i_2 as p1_i_2,
    dados.p1_j as p1_j,
    dados.p1_k as p1_k,
    dados.p1_l as p1_l,
    dados.p1_m as p1_m,
    dados.p2_a as p2_a,
    dados.p2_b as p2_b,
    dados.p2_c as p2_c,
    dados.p2_d as p2_d,
    dados.p2_e as p2_e,
    dados.p2_f as p2_f,
    dados.p2_g as p2_g,
    dados.p2_h as p2_h,
    dados.p2_i as p2_i,
    dados.p2_j as p2_j,
    dados.p2_k as p2_k,
    dados.p2_l as p2_l,
    dados.p2_l_1 as p2_l_1,
    dados.p2_l_2 as p2_l_2,
    dados.p2_l_3 as p2_l_3,
    dados.p2_l_4 as p2_l_4,
    dados.p2_l_5 as p2_l_5,
    dados.p2_l_6 as p2_l_6,
    dados.p2_l_7 as p2_l_7,
    dados.p2_m as p2_m,
    dados.p2_n as p2_n,
    dados.p2_o as p2_o,
    dados.p2_o_1 as p2_o_1,
    dados.p2_o_2 as p2_o_2,
    dados.p2_o_3 as p2_o_3,
    dados.p2_o_4 as p2_o_4,
    dados.p2_o_5 as p2_o_5,
    dados.p2_o_6 as p2_o_6,
    dados.p2_o_7 as p2_o_7,
    dados.p2_o_8 as p2_o_8,
    dados.p2_o_9 as p2_o_9,
    dados.p2_o_10 as p2_o_10,
    dados.p2_p as p2_p,
    dados.p2_q as p2_q,
    dados.p2_r as p2_r,
    dados.p2_s as p2_s,
    dados.p3_a as p3_a,
    dados.p3_b as p3_b,
    dados.p3_b_1 as p3_b_1,
    dados.p3_b_2 as p3_b_2,
    dados.p3_b_3 as p3_b_3,
    dados.p3_b_4 as p3_b_4,
    dados.p3_b_5 as p3_b_5,
    dados.p3_b_6 as p3_b_6,
    dados.p3_b_7 as p3_b_7,
    dados.p3_b_8 as p3_b_8,
    dados.p3_b_9 as p3_b_9,
    dados.p3_c as p3_c,
    dados.p3_c_1 as p3_c_1,
    dados.p3_c_2 as p3_c_2,
    dados.p3_c_3 as p3_c_3,
    dados.p3_c_4 as p3_c_4,
    dados.p3_c_5 as p3_c_5,
    dados.p3_c_6 as p3_c_6,
    dados.p3_c_7 as p3_c_7,
    dados.p3_c_8 as p3_c_8,
    dados.p3_c_9 as p3_c_9,
    dados.p3_c_10 as p3_c_10,
    dados.p3_c_11 as p3_c_11,
    dados.p3_d as p3_d,
    dados.p3_d_1 as p3_d_1,
    dados.p3_d_2 as p3_d_2,
    dados.p3_d_3 as p3_d_3,
    dados.p3_d_4 as p3_d_4,
    dados.p3_d_5 as p3_d_5,
    dados.p3_d_6 as p3_d_6,
    dados.p3_d_7 as p3_d_7,
    dados.p3_d_8 as p3_d_8,
    dados.p3_d_9 as p3_d_9,
    dados.p3_d_10 as p3_d_10,
    dados.p3_d_11 as p3_d_11,
    dados.p3_d_12 as p3_d_12,
    dados.p3_d_13 as p3_d_13,
    dados.p3_d_14 as p3_d_14,
    dados.p4_a as p4_a,
    dados.p4_a_1 as p4_a_1,
    dados.p4_b as p4_b,
    dados.p4_b_1 as p4_b_1,
    dados.p4_b_2 as p4_b_2,
    dados.p4_b_3 as p4_b_3,
    dados.p4_b_4 as p4_b_4,
    dados.p4_b_5 as p4_b_5,
    dados.p4_b_6 as p4_b_6,
    dados.p4_b_7 as p4_b_7,
    dados.p4_b_8 as p4_b_8,
    dados.p4_c as p4_c,
    dados.p4_c_1 as p4_c_1,
    dados.p4_c_2 as p4_c_2,
    dados.p4_c_3 as p4_c_3,
    dados.p4_c_4 as p4_c_4,
    dados.p4_c_5 as p4_c_5,
    dados.p4_c_6 as p4_c_6,
    dados.p4_c_7 as p4_c_7,
    dados.p4_c_8 as p4_c_8,
    dados.p4_d as p4_d,
    dados.p4_d_1 as p4_d_1,
    dados.p4_d_2 as p4_d_2,
    dados.p4_d_3 as p4_d_3,
    dados.p4_d_4 as p4_d_4,
    dados.p4_d_5 as p4_d_5,
    dados.p4_d_6 as p4_d_6,
    dados.p4_d_7 as p4_d_7,
    dados.p4_d_8 as p4_d_8,
    dados.p4_d_9 as p4_d_9,
    dados.p4_d_10 as p4_d_10,
    dados.p4_d_11 as p4_d_11,
    dados.p4_d_12 as p4_d_12,
    dados.p4_d_13 as p4_d_13,
    dados.p4_d_14 as p4_d_14,
    dados.p4_e as p4_e,
    dados.p4_f as p4_f,
    dados.p4_g as p4_g,
    dados.p4_g_1 as p4_g_1,
    dados.p4_g_2 as p4_g_2,
    dados.p4_g_3 as p4_g_3,
    dados.p4_f_4 as p4_f_4,
    dados.p4_f_5 as p4_f_5,
    dados.p6_b_5 as p6_b_5,
    dados.p6_b_6 as p6_b_6,
    dados.p6_b_7 as p6_b_7,
    dados.p6_b_8 as p6_b_8,
    dados.p6_b_9 as p6_b_9,
    dados.p6_b_10 as p6_b_10,
    dados.p6_b_11 as p6_b_11,
    dados.p6_b_12 as p6_b_12,
    dados.p6_b_13 as p6_b_13,
    dados.p6_b_14 as p6_b_14,
    dados.p6_b_15 as p6_b_15,
    dados.p6_b_16 as p6_b_16,
    dados.p6_b_17 as p6_b_17,
    dados.p6_b_18 as p6_b_18,
    dados.p6_b_19 as p6_b_19,
    dados.p6_b_19__1 as p6_b_19__1,
    dados.p6_c as p6_c,
    dados.p6_d as p6_d,
    dados.p6_e as p6_e,
    dados.p6_f as p6_f,
    dados.p6_g as p6_g,
    dados.p6_g_1 as p6_g_1,
    dados.p6_g_2 as p6_g_2,
    dados.p6_g_3 as p6_g_3,
    dados.p6_g_4 as p6_g_4,
    dados.p6_g_5 as p6_g_5,
    dados.p6_g_6 as p6_g_6,
    dados.p6_g_7 as p6_g_7,
    dados.p6_g_8 as p6_g_8,
    dados.p6_g_9 as p6_g_9,
    dados.p6_g_10 as p6_g_10,
    dados.p6_g_11 as p6_g_11,
    dados.p6_g_l as p6_g_l,
    dados.p6_g_m as p6_g_m,
    dados.p6_h as p6_h,
    dados.p6_h_1 as p6_h_1,
    dados.p6_h_2 as p6_h_2,
    dados.p6_h_3 as p6_h_3,
    dados.p6_h_4 as p6_h_4,
    dados.p6_h_5 as p6_h_5,
    dados.p6_h_6 as p6_h_6,
    dados.p6_h_7 as p6_h_7,
    dados.p6_h_8 as p6_h_8,
    dados.p6_h_9 as p6_h_9,
    dados.p7_1 as p7_1,
    dados.p7_a_1 as p7_a_1,
    dados.p7_a_2 as p7_a_2,
    dados.p7_a_3 as p7_a_3,
    dados.p7_a_4 as p7_a_4,
    dados.p7_a_5 as p7_a_5,
    dados.p7_a_6 as p7_a_6,
    dados.p7_a_7 as p7_a_7,
    dados.p7_a_8 as p7_a_8,
    dados.p7_a_9 as p7_a_9,
    dados.p7_a_10 as p7_a_10,
    dados.p7_b as p7_b,
    dados.p7_b_1 as p7_b_1,
    dados.p7_b_2 as p7_b_2,
    dados.p7_b_3 as p7_b_3,
    dados.p7_b_4 as p7_b_4,
    dados.p7_b_5 as p7_b_5,
    dados.p7_b_6 as p7_b_6,
    dados.p7_b_7 as p7_b_7,
    dados.p7_b_8 as p7_b_8,
    dados.p7_b_9 as p7_b_9,
    dados.p7_b_10 as p7_b_10,
    dados.p7_b_11 as p7_b_11,
    dados.p7_b_12 as p7_b_12,
    dados.p7_b_13 as p7_b_13,
    dados.p7_b_14 as p7_b_14,
    dados.p7_b_15 as p7_b_15,
    dados.p7_b_16 as p7_b_16,
    dados.p7_b_17 as p7_b_17,
    dados.p7_b_18 as p7_b_18,
    dados.p7_b_19 as p7_b_19,
    dados.p7_b_20 as p7_b_20,
    dados.p7_c as p7_c,
    dados.p7_c_1 as p7_c_1,
    dados.p7_c_2 as p7_c_2,
    dados.p7_c_3 as p7_c_3,
    dados.p7_c_4 as p7_c_4,
    dados.p7_c_5 as p7_c_5,
    dados.p7_c_6 as p7_c_6,
    dados.p7_d as p7_d,
    dados.p7_d_1 as p7_d_1,
    dados.p7_d_2 as p7_d_2,
    dados.p7_d_3 as p7_d_3,
    dados.p7_d_4 as p7_d_4,
    dados.p7_d_5 as p7_d_5,
    dados.p7_d_6 as p7_d_6,
    dados.p7_d_7 as p7_d_7,
    dados.p7_d_8 as p7_d_8,
    dados.p7_d_9 as p7_d_9,
    dados.p7_d_10 as p7_d_10,
    dados.p8_a as p8_a,
    dados.p8_a_1 as p8_a_1,
    dados.p8_a_2 as p8_a_2,
    dados.p8_a_3 as p8_a_3,
    dados.p8_a_4 as p8_a_4,
    dados.p8_a_5 as p8_a_5,
    dados.p8_a_6 as p8_a_6,
    dados.p8_a_7 as p8_a_7,
    dados.p8_a_8 as p8_a_8,
    dados.p8_a_9 as p8_a_9,
    dados.p8_a_10 as p8_a_10,
    dados.p8_a_11 as p8_a_11,
    dados.p8_b as p8_b,
    dados.p8_b_1 as p8_b_1,
    dados.p8_b_2 as p8_b_2,
    dados.p8_b_3 as p8_b_3,
    dados.p8_b_4 as p8_b_4,
    dados.p8_b_5 as p8_b_5,
    dados.p8_b_6 as p8_b_6,
    dados.p8_b_7 as p8_b_7,
    dados.p8_b_8 as p8_b_8,
    dados.p8_b_9 as p8_b_9,
    dados.p8_b_10 as p8_b_10,
    dados.p8_b_11 as p8_b_11,
    dados.p8_b_l as p8_b_l,
    dados.p8_b_m as p8_b_m,
    dados.p8_3 as p8_3,
    dados.p8_c_1 as p8_c_1,
    dados.p8_c_2 as p8_c_2,
    dados.p8_c_3 as p8_c_3,
    dados.p8_c_4 as p8_c_4,
    dados.p8_c_5 as p8_c_5,
    dados.p8_c_6 as p8_c_6,
    dados.p8_c_7 as p8_c_7,
    dados.p8_c_8 as p8_c_8,
    dados.p8_c_9 as p8_c_9,
    dados.p8_c_10 as p8_c_10,
    dados.p8_c_11 as p8_c_11,
    dados.p8_d as p8_d,
    dados.p8_d_1 as p8_d_1,
    dados.p8_d_2 as p8_d_2,
    dados.p8_d_3 as p8_d_3,
    dados.p8_d_4 as p8_d_4,
    dados.p8_d_5 as p8_d_5,
    dados.p8_d_6 as p8_d_6,
    dados.p8_d_7 as p8_d_7,
    dados.p8_d_8 as p8_d_8,
    dados.p8_d_9 as p8_d_9,
    dados.p8_d_10 as p8_d_10,
    dados.p8_d_11 as p8_d_11
FROM `basedosdados.br_datahackers_state_data.microdados` AS dados
"""

bd.read_sql(query = query, billing_project_id = data-marketplace-466013:US.bquxjob_690c1003_1980e510b06)
# Out:
#   Cell In[211], line 3
#     billing_id = <seu_billing_id>
#                  ^
# SyntaxError: invalid syntax
